# %%
# DEBER DE BIONFORMATICA

# %%
# Importamos las librerias que necesitamos
import re
import csv 
import pandas as pd
import matplotlib.pyplot as plt
import itertools

# %%
# Abrimos el archivo y leemos 
import re
with open('pubmed-lipidnanop-set.txt',"r", encoding='utf-8-sig') as f:
    paises_data = f.read()
len(paises_data)
# Out:
# 12850498

# %%
# Reemplazamos cada línea nueva continuado de 6 espacios con un solo espacio e imprimimos 
import re
paises_data = re.sub(r'\n\s{6}',' ', paises_data)

# %%
 data = re.findall(r"\,\s[A-Z]+[A-z]{2,11}\.", paises_data)

# %%
unique_data =list(set(data))
unique_data.sort()
x = unique_data
print(x)
r = unique_data
r.remove(', Austria.')
r.remove(', Avda.')
r.remove(', Avgda.')
r.remove(', Azerbaijan.')
r.remove(', Bangladesh.')
r.remove(', Barcelona.')
r.remove(', Basel.')
r.remove(', Beijing.')
r.remove(', Belgium.')
r.remove(', Bldg.')
r.remove(', Bolivia.')
r.remove(', Brasil.')
r.remove(', Bulgaria.')
r.remove(', Butenandtstr.')
r.remove(', Cairo.')
r.remove(', Calif.')
r.remove(', California.')
r.remove(', Canada.')
r.remove(', Catania.')
r.remove(', Chile.')
r.remove(', Chr.') 
r.remove(', Col.') 
r.remove(', Colombia.') 
r.remove(', Croatia.') 
r.remove(', Ctra.') 
r.remove(', Cuba.')
r.remove( ', Cyprus.')
r.remove(', Del.')
r.remove(', Denmark.')
r.remove(', Dept.')
r.remove(', Depto.')
r.remove(', Deutschland.')
r.remove(', Dist.')
r.remove(', Distt.') 
r.remove(', Domagkstr.')
r.remove(', Dominica.')
r.remove(', Dpto.')
r.remove(', EAACI.')
r.remove(', Ecuador.')
r.remove(', Edo.')
r.remove(', Egypt.')
r.remove(', Estonia.')
r.remove(', Ethiopia.')
r.remove(', Finland.')
r.remove(', Fla.')
r.remove(', France.')
r.remove(', Gabon.')
r.remove(', Gal.')
r.remove(', Gambia.')
r.remove(', Germany.')
r.remove(', Ghana.')
r.remove(', Govt.')
r.remove(', Granada.')
r.remove(', Greece.')
r.remove(', Guangzhou.')
r.remove( ', HPPH.')
r.remove(', Hangzhou.')
r.remove(', Hochstr.')
r.remove(', Hungary.')
r.remove(', INDIA.')
r.remove(', Iceland.')
r.remove(', Inc.')
r.remove(', India.')
r.remove(', Indonesia.')
r.remove(', Inst.')
r.remove(', Iran.')
r.remove(', Iraq.')
r.remove(', Ireland.')
r.remove(', Islamabad.')
r.remove(', Israel.')
r.remove(', Istanbul.')
r.remove(', Italfarmaco.')
r.remove(', Italy.')
r.remove(', Japan.')
r.remove(', Jenjarom.')
r.remove(', Jiaxing.')
r.remove(', Jordan.')
r.remove(', Kaiserstr.')
r.remove(', Karachi.')
r.remove(', Kazakhstan.')
r.remove(', Kelchstr.')
r.remove(', Kenya.')
r.remove(', Kohat.')
r.remove(', Korea.')
r.remove(', Kuwait.')
r.remove(', LLC.')
r.remove(', Lahore.')
r.remove(', Lebanon.')
r.remove(', Ltd.')
r.remove(', Lucknow.')
r.remove(', Makkah.')
r.remove(', Malaysia.')
r.remove( ', Mali.')
r.remove(', Mass.')
r.remove(', Mauritius.')
r.remove(', Mexico.')
r.remove(', Morocco.')
r.remove(', Mumbai.')
r.remove(', Namibia.')
r.remove(', Nepal.')
r.remove(', Netherlands.')
r.remove(', Nigeria.')
r.remove(', Notkestr.')
r.remove(', Ohio.') 
r.remove(', Oman.')
r.remove(', Onpattro.')
r.remove(', Ont.')
r.remove(', Opp.')
r.remove(', Oregon.')
r.remove(', Pakistan.')
r.remove(', Palestine.')
r.remove(', Pamplona.')
r.remove(', Pauwelsstr.')
r.remove(', Pavia.')
r.remove(', Pittsburgh.')
r.remove(', Poland.')
r.remove(', Porto.')
r.remove(', Portugal.')
r.remove(', Prof.')
r.remove(', Punjab.')
r.remove(', Pvt.')
r.remove(', Qatar.')
r.remove(', ROC.')
r.remove(', Romania.')
r.remove(', Russia.')
r.remove(', Scotland.',)
r.remove(', Selangor.')
r.remove(', Senegal.')
r.remove(', Serbia.')
r.remove(', Serdang.')
r.remove(', Shihezi.',)
r.remove(', Singapore.')
r.remove(', Slovenia.')
r.remove(', Spain.')
r.remove(', Staudtstr.')
r.remove(', Sudan.')
r.remove(', Sweden.')
r.remove(', Switzerland.')
r.remove(', Syria.')
r.remove(', Taiwan.')
r.remove(', Tanzania.')
r.remove(', Technikerstr.')
r.remove(', Tenn.')
r.remove(', Texas.')
r.remove(', Thailand.')
r.remove(', Tunisia.')
r.remove(', Turkey.')
r.remove(', UAE.')
r.remove(', AddaVax.')
r.remove(', Afghanistan.')
r.remove(', Algeria.')
r.remove(', Argentina.')
r.remove(', Univ.')
r.remove(', Uruguay.')
r.remove(', Valencia.')
r.remove(', Varanasi.')
r.remove(', Vietnam.')
r.remove(', Wales.')
r.remove(', Washington.')
r.remove(', Weinheim.')
r.remove(', Yemen.')
r.remove(', Zambia.')
r.remove(', Zimbabwe.')
# Out:
# [', AddaVax.', ', Afghanistan.', ', Algeria.', ', Argentina.', ', Australia.', ', Austria.', ', Avda.', ', Avgda.', ', Azerbaijan.', ', Bangladesh.', ', Barcelona.', ', Basel.', ', Beijing.', ', Belgium.', ', Bldg.', ', Bolivia.', ', Brasil.', ', Brazil.', ', Bulgaria.', ', Butenandtstr.', ', Cairo.', ', Calif.', ', California.', ', Canada.', ', Catania.', ', Chile.', ', China.', ', Chr.', ', Col.', ', Colombia.', ', Croatia.', ', Ctra.', ', Cuba.', ', Cyprus.', ', Del.', ', Denmark.', ', Dept.', ', Depto.', ', Deutschland.', ', Dist.', ', Distt.', ', Domagkstr.', ', Dominica.', ', Dpto.', ', EAACI.', ', Ecuador.', ', Edo.', ', Egypt.', ', Estonia.', ', Ethiopia.', ', Finland.', ', Fla.', ', France.', ', Gabon.', ', Gal.', ', Gambia.', ', Germany.', ', Ghana.', ', Govt.', ', Granada.', ', Greece.', ', Guangzhou.', ', HPPH.', ', Hangzhou.', ', Hochstr.', ', Hungary.', ', INDIA.', ', Iceland.', ', Inc.', ', India.', ', Indonesia.', ', Inst.', ', Iran.', ', Iraq.', ', Ireland.', ', Isla
# ...

# %%
print()
print(r)
# Out:
# [', Australia.', ', Brazil.', ', China.', ', Norway.', ', USA.']

# %%
    text = "".join(r)
    text2 = text.split(", ")
    text3 = "".join(text2)
    text4 = text3.split(".")
    text4.remove("")
    text5 = text4
    print()
    print('Lista de países: ', text5)
# Out:
# Lista de países:  ['Australia', 'Brazil', 'China', 'Norway', 'USA']

# %%
import csv
import pandas as pd
dat = pd.read_csv('./Latitud_longitud.csv', engine='python', skipfooter=3)
dat.head(10)
# Out:
#                                           country   latitude  longitude  \
# 0                                              AD  42.546245   1.601554
# 1   AE,23.424076,53.847818,"United Arab Emirates"        NaN        NaN
# 2                                              AF  33.939110  67.709953
# 3   AG,17.060816,-61.796428,"Antigua and Barbuda"        NaN        NaN
# 4                                              AI  18.220554 -63.068615
# 5                                              AL  41.153332  20.168331
# 6                                              AM  40.069099  45.038189
# 7  AN,12.226079,-69.060087,"Netherlands Antilles"        NaN        NaN
# 8                                              AO -11.202692  17.873887
# 9                                              AQ -75.250973  -0.071389
#
#           name
# 0      Andorra
# 1         None
# 2  Afghanistan
# 3         None
# 4     Anguilla
# 5      Albania
# 6      Armenia
# 7         None
# 8       Angola
# ...

# %%
name = dat[dat.name.isin(text5)]
name.head(10)
# Out:
#     country   latitude   longitude       name
# 13       AU -25.274398  133.775136  Australia
# 28       BR -14.235004  -51.925280     Brazil
# 45       CN  35.861660  104.195397      China
# 163      NO  60.472024    8.468946     Norway

# %%
paises = dat[dat.country.isin(text5)]
final =pd.concat([name,paises]).drop_duplicates().sort_values('name')
final.head(10)
# Out:
#     country   latitude   longitude       name
# 13       AU -25.274398  133.775136  Australia
# 28       BR -14.235004  -51.925280     Brazil
# 45       CN  35.861660  104.195397      China
# 163      NO  60.472024    8.468946     Norway

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(final.longitude, final.latitude, s=50, c=final.latitude)
plt.colorbar()

# Lugares Señalados 
ard = dict(arrowstyle="->")

plt.annotate('USA', xy = (-95.712891, 37.09024), 
               xytext = (-95.712891, 40), arrowprops = ard)
plt.annotate('UKRAINE', xy = (31.16558,48.379433), 
               xytext = (31.16558,51), arrowprops= ard)
plt.annotate('BRAZIL', xy = (-51.92528, -14.235004), 
               xytext = (-51.92528, -11), arrowprops= ard)
plt.annotate('CHINA', xy = (104.195397, 35.86166), 
               xytext = (104.195397, 39), arrowprops= ard)
plt.annotate('AUSTRALIA', xy = (133.775136, -25.274398), 
               xytext = (133.775136, -22), arrowprops= ard)
plt.annotate('NORWAY', xy = (8.468946, 60.472024), 
               xytext = (8.468946, 63), arrowprops= ard)

params = plt.gcf()
plSize = params.get_size_inches()
params.set_size_inches( (plSize[0] * 3, plSize[1] * 3) )
